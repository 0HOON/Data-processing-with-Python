# %% [markdown]
# # 7. 시계열 데이터를 다뤄보자

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from fbprophet import Prophet
from datetime import datetime
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
path = "c:/Windows/Fonts/malgun.ttf"
import platform 
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)

plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ##  pinkwink 블로그 조회수 살펴보기

# %%
pinkwink_web = pd.read_csv('data/08. PinkWink Web Traffic.csv', encoding='utf-8', thousands=',', names = ['date', 'hit'], index_col=0)
pinkwink_web = pinkwink_web[pinkwink_web['hit'].notnull()]
pinkwink_web.head()
# Out:
#              hit
# date
# 16. 7. 1.  766.0
# 16. 7. 2.  377.0
# 16. 7. 3.  427.0
# 16. 7. 4.  902.0
# 16. 7. 5.  850.0

# %%
pinkwink_web['hit'].plot(figsize=(12,4), grid=True)

# %%
time = np.arange(0, len(pinkwink_web))
traffic = pinkwink_web['hit'].values
fx = np.linspace(0, time[-1], 1000)

# %%
def error(f, x, y):
    return np.sqrt(np.mean((f(x)-y)**2))

# %%
fp1 = np.polyfit(time, traffic, 1)
f1 = np.poly1d(fp1)

fp2 = np.polyfit(time, traffic, 2)
f2 = np.poly1d(fp2)

fp3 = np.polyfit(time, traffic, 3)
f3 = np.poly1d(fp3)

fp15 = np.polyfit(time, traffic, 15)
f15 = np.poly1d(fp15)

print(error(f1, time, traffic))
print(error(f2, time, traffic))
print(error(f3, time, traffic))
print(error(f15, time, traffic))
# Out:
# 430.8597308110963
# 430.6284101894695
# 429.53280466762925
# 330.47773039540385

# %%
plt.figure(figsize=(10, 6))
plt.scatter(time, traffic, s=10)

plt.plot(fx, f1(fx), lw=4, label='f1')
plt.plot(fx, f2(fx), lw=4, label='f2')
plt.plot(fx, f3(fx), lw=4, label='f3')
plt.plot(fx, f15(fx), lw=4, label='f15')

plt.grid(True, linestyle='-', color='0.75')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ## Prophet

# %%
df = pd.DataFrame({'ds':pinkwink_web.index, 'y':pinkwink_web['hit']})
df.reset_index(inplace=True)
df['ds'] = pd.to_datetime(df['ds'], format="%y. %m. %d.")
del df['date']

m = Prophet(yearly_seasonality=True)
m.fit(df);
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=60)
future.tail()
# Out:
#             ds
# 420 2017-08-25
# 421 2017-08-26
# 422 2017-08-27
# 423 2017-08-28
# 424 2017-08-29

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 420 2017-08-25   912.761130   691.315532  1133.850352
# 421 2017-08-26   497.711704   270.850399   706.817646
# 422 2017-08-27   630.268176   416.655089   825.247856
# 423 2017-08-28  1182.888299   970.317947  1399.875390
# 424 2017-08-29  1218.800002  1001.662689  1430.615604

# %%
forecast
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   2016-07-01  1059.263169   521.336299   933.252562  1059.263169
# 1   2016-07-02  1060.117429    84.669558   509.138491  1060.117429
# 2   2016-07-03  1060.971688   218.306963   636.257323  1060.971688
# 3   2016-07-04  1061.825948   765.719399  1187.116694  1061.825948
# 4   2016-07-05  1062.680207   784.529557  1219.365336  1062.680207
# ..         ...          ...          ...          ...          ...
# 420 2017-08-25  1418.175623   691.315532  1133.850352  1418.174224
# 421 2017-08-26  1419.030223   270.850399   706.817646  1419.028796
# 422 2017-08-27  1419.884824   416.655089   825.247856  1419.883370
# 423 2017-08-28  1420.739425   970.317947  1399.875390  1420.737951
# 424 2017-08-29  1421.594025  1001.662689  1430.615604  1421.592505
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    1059.263169     -330.262778           -330.262778           -330.262778
# ...

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
import yfinance as yf
yf.pdr_override()

start = '2010-1-1'
end = '2019-6-30'

NHN = web.get_data_yahoo('181710.KS',start, end)
NHN.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2013-08-28  144387.0  144387.0  144387.0  144387.0   144387.0        0
# 2013-08-29  144387.0  144387.0  123139.0  123139.0   123139.0    34540
# 2013-08-30  104789.0  107686.0  104789.0  104789.0   104789.0  5308289
# 2013-09-02  106238.0  110584.0  104306.0  110101.0   110101.0  1765259
# 2013-09-03  110584.0  111067.0  106238.0  106238.0   106238.0   629452

# %%
NHN['Close'].plot(figsize=(12,6), grid=True)

# %%
NHN_trunc = NHN[:'2018-12-31']
NHN_trunc
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2013-08-28  144387.0  144387.0  144387.0  144387.0   144387.0        0
# 2013-08-29  144387.0  144387.0  123139.0  123139.0   123139.0    34540
# 2013-08-30  104789.0  107686.0  104789.0  104789.0   104789.0  5308289
# 2013-09-02  106238.0  110584.0  104306.0  110101.0   110101.0  1765259
# 2013-09-03  110584.0  111067.0  106238.0  106238.0   106238.0   629452
# ...              ...       ...       ...       ...        ...      ...
# 2018-12-21   56000.0   56700.0   55000.0   56700.0    56700.0    54220
# 2018-12-24   56800.0   57500.0   56300.0   57300.0    57300.0    42648
# 2018-12-26   56200.0   57000.0   54800.0   55700.0    55700.0    24938
# 2018-12-27   56800.0   57600.0   56400.0   57000.0    57000.0    73268
# 2018-12-28   56800.0   57600.0   56200.0   57300.0    57300.0    24078
#
# [1304 rows x 6 columns]

# %%
df = pd.DataFrame({'ds':NHN_trunc.index, 'y':NHN_trunc['Close']})
df.reset_index(inplace=True)
del df['Date']
df.head()
# Out:
#           ds         y
# 0 2013-08-28  144387.0
# 1 2013-08-29  123139.0
# 2 2013-08-30  104789.0
# 3 2013-09-02  110101.0
# 4 2013-09-03  106238.0

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 1664 2019-12-24
# 1665 2019-12-25
# 1666 2019-12-26
# 1667 2019-12-27
# 1668 2019-12-28

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds          yhat    yhat_lower    yhat_upper
# 1664 2019-12-24  36995.294776   8863.455351  63500.323563
# 1665 2019-12-25  37095.012411  10697.917303  63803.466717
# 1666 2019-12-26  36845.606864   9916.003982  62737.620987
# 1667 2019-12-27  36754.450225  10256.835285  63787.554282
# 1668 2019-12-28  54451.134809  26471.343387  80513.467375

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
start = '2010-1-1'
end = '2018-12-31'

NHN = web.get_data_yahoo('181710.KS',start, end)
NHN['Close'].plot(figsize=(12,6), grid=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
NHN_trunc = NHN[:'2018-10-31']
NHN_trunc['Close'].plot(figsize=(12,6), grid=True)

# %%
df = pd.DataFrame({'ds':NHN_trunc.index, 'y':NHN_trunc['Close']})
df.reset_index(inplace=True)
del df['Date']

# %%
m = Prophet()

# %%
m.fit(df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=61)
future.tail()
# Out:
#              ds
# 1320 2018-12-27
# 1321 2018-12-28
# 1322 2018-12-29
# 1323 2018-12-30
# 1324 2018-12-31

# %%
forecast = m.predict(future)
m.plot(forecast)

# %%
plt.figure(figsize=(12,6))
plt.plot(NHN.index, NHN['Close'], label='real')
plt.plot(forecast['ds'], forecast['yhat'], label='forecast')
plt.grid()
plt.legend()
plt.show()
